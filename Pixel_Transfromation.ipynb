# %% [markdown]
# # Pixel Transformation
# - Histograms
# - Intensity Transformations
# - Thresholding and simple segamentation
#
# ----------------------
#
# # Historgram
# - Defintion: count number of currency of **pixels and intensity values** and a useful tool for understanding images
# - we use `calcHist()` function generate historgram.
# - code model:
#
# `import cv2`
#
# `goldhill=cv2.imread('goldhill.bmp')`
#
# `hist=calcHist([goldhill],[0], None, [256], [0,256])`   #(image_name,the channel we want to calculate this time we use the grayscale,  ,the number of channels, the range of in4
# tensity values the range of index of bins)
# - we plot the histogram as a bar graph, the darker part mains lower intensity, the brighter corresponds to higher values.
#
# -------------------------
# # Intensity Transformations
# - transform one pixel at a time
# - some pixel's transformation depends on neighborhood pixels
#
#    ***g[i,j]=T{f[i,j]}***
#    - f:image array
#    - T: intensity transformation
#
#   ***S=T{r}***
#   - r: intensity of grey level
#
# #image Negative
# - Defintion: reverse the intensity level of an image
# - Codes model:
#
# `image=cv2.imread('mammomgram.png',cv2.IMREAD_GRAYSCALE)`
#
# `img_neg=-1*image+255`   #g[i,j]=-1*f[i,j]+255
#
# #Linear Transform: Brightness and Contrast Adjustment
# - ***g[i,j]=𝛼f[i,j]+𝛽***
#   - 𝛼:simple contrast control
#   - 𝛽:simple brightness control
#
# - Codes model: after transformation we use `convertScaleAbs` function, calculate the absoluate values, the intensity range from (0,255)
#
# `new_image=cv2.convertScaleAbs(goldhill,alpha=1,beta=100)`
#
# #Adjust Contrast:Historgram Equalization
#
# `zelda=cv2.imread('zelda.img,cv2.IMREAD_GRAYSCALE)`
#
# `new_img=cv2.equalizeHist(zelda)` #flatten the image and improve the contrast.
#
# ----------------------
# #Thresholding and simple segamentation
# - Segament: Extract objects from an image
# - Code:
#
# `def thresholding(input_img, threshold, max_value=255, min_value=0):`
#
#     N,M=input_img.shape
#
#     img_out=np.zeros((N,M),dtype=np.unit8)
#
#     for i in range(N):
#
#       for j in range(M):
#
#        if input_img[i,j]>threshold:
#
#          img_out[i,j]=max_value
#
#       else:
#
#         img_out[i,j]=min_value
#
#     return img_out
#
#
#
#
#
# - `cv.threshold(grayscale image, threshold value, maximum value to use, thresholding type)`
#    - `cv2.THRESH_BINARY`: use the pre-set threshold;
#    -  `cv2.THRESH_OTSU`: automatically select the threshold

# %%
#import graphs from library
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/baboon.png -O baboon.png
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/cameraman.jpeg -O cameraman.jpeg
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/mammogram.png -O mammogram.png
# Out:
# --2022-09-13 05:02:07--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/baboon.png
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.45.118.108
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.45.118.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 637192 (622K) [image/png]
# Saving to: ‘baboon.png’
#
# baboon.png          100%[===================>] 622.26K   276KB/s    in 2.3s
#
# 2022-09-13 05:02:11 (276 KB/s) - ‘baboon.png’ saved [637192/637192]
#
# --2022-09-13 05:02:11--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-CV0101EN-SkillsNetwork/images%20/images_part_1/cameraman.jpeg
# ...

# %%
#import the py-package
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
#we define the function for plotting photos 2 by 2
def plot_image(image_1, image_2,title_1="Orignal", title_2="New Image"):
    plt.figure(figsize=(10,10))
    plt.subplot(1, 2, 1)
    plt.imshow(image_1,cmap="gray")
    plt.title(title_1)
    plt.subplot(1, 2, 2)
    plt.imshow(image_2,cmap="gray")
    plt.title(title_2)
    plt.show()

# %%
def plot_hist(old_image, new_image,title_old="Orignal", title_new="New Image"):
    intensity_values=np.array([x for x in range(256)])
    plt.subplot(1, 2, 1)
    plt.bar(intensity_values, cv2.calcHist([old_image],[0],None,[256],[0,256])[:,0],width = 5)
    plt.title(title_old)
    plt.xlabel('intensity')
    plt.subplot(1, 2, 2)
    plt.bar(intensity_values, cv2.calcHist([new_image],[0],None,[256],[0,256])[:,0],width = 5)
    plt.title(title_new)
    plt.xlabel('intensity')
    plt.show()

# %% [markdown]
# # Histograms

# %%
#toy image with intensity values ranging from 0 to 2.
toy_image = np.array([[0,2,2],[1,1,1],[1,1,2]],dtype=np.uint8)
plt.imshow(toy_image, cmap="gray")
plt.show()
print("toy_image:",toy_image)
# Out:
# toy_image: [[0 2 2]
#  [1 1 1]
#  [1 1 2]]

# %%
plt.bar([x for x in range(6)],[1,5,2,0,0,0])
plt.show()

# %%
plt.bar([x for x in range(6)],[0,1,0,5,0,2])
plt.show()

# %% [markdown]
# The histogram is a function where $h[r] where   $r in {0,1,2} $. In the above example  $h[0]=1$,$h[1]=5$ and $h[2]=3$

# %% [markdown]
# # Gray Scale Histograms

# %%
DW= cv2.imread("DorisWang.jpg",cv2.IMREAD_GRAYSCALE)
plt.figure(figsize=(10,10))
plt.imshow(DW,cmap="gray")
plt.show()

# %%
#We can calculate the histogram using the calcHist function from the cv2 module as follows, the shape is 256.
hist = cv2.calcHist([DW],[0], None, [256], [0,256])

# %%
#plot the intensity graph, x: pixel intensity, y: # of occurrences that the corresponding pixel intensity value on x
intensity_values = np.array([x for x in range(hist.shape[0])])
plt.bar(intensity_values, hist[:,0], width = 5)
plt.title("Bar histogram")
plt.show()

# %% [markdown]
# We can convert it to a `probability mass function` by *normalizing it by the number of pixels*

# %%
PMF = hist / (DW.shape[0] * DW.shape[1])

# %%
plt.plot(intensity_values,hist)
plt.title("histogram")
plt.show()

# %% [markdown]
# We now discover each color channel:

# %%
baboon = cv2.imread("baboon.png")
plt.imshow(cv2.cvtColor(baboon,cv2.COLOR_BGR2RGB))
plt.show()

# %%
color = ('blue','green','red')
for i,col in enumerate(color):
    histr = cv2.calcHist([baboon],[i],None,[256],[0,256])
    plt.plot(intensity_values,histr,color = col,label=col+" channel")
    plt.xlim([0,256])
    
plt.legend()
plt.title("Histogram Channels")
plt.show()

# %% [markdown]
# # Intensity Transformation
# - Image Negative

# %%
neg_toy_image = -1 * toy_image + 255

print("toy image\n", neg_toy_image)
print("image negatives\n", neg_toy_image)
# Out:
# toy image
#  [[255 253 253]
#  [254 254 254]
#  [254 254 253]]
# image negatives
#  [[255 253 253]
#  [254 254 254]
#  [254 254 253]]

# %%
plt.figure(figsize=(10,10))
plt.subplot(1, 2, 1) 
plt.imshow(toy_image,cmap="gray")

plt.subplot(1, 2, 2)
plt.imshow(neg_toy_image,cmap="gray")

plt.show()
print("toy_image:",toy_image)
# Out:
# toy_image: [[0 2 2]
#  [1 1 1]
#  [1 1 2]]

# %% [markdown]
# The darker intensity’s become brighter,the brighter become darker, middle intensity’s remain the same.

# %%
#the reverse image transformation applicate in medical area
image = cv2.imread("mammogram.png", cv2.IMREAD_GRAYSCALE)
cv2.rectangle(image, pt1=(160, 212), pt2=(250, 289), color = (255), thickness=2) 

plt.figure(figsize = (10,10))
plt.imshow(image, cmap="gray")
plt.show()

# %%
img_neg = -1 * image + 255
plt.figure(figsize=(10,10))
plt.imshow(img_neg, cmap = "gray")
plt.show() #the micro-calcifications in the image negatives is easier than original one

# %% [markdown]
# # Brightness and contrast adjustments

# %%
#Simple contrast control
alpha = 1 
# Simple brightness control  
beta = 150   
brighter_image = cv2.convertScaleAbs(DW, alpha=alpha, beta=beta)

# %%
plot_image(DW,brighter_image, title_1 = "Orignal", title_2 = "brightness control")

# %%
#get the histrogram
plt.figure(figsize=(10,5))
plot_hist(DW, brighter_image, "Orignal", "brightness control")

# %%
#increase the contrast
plt.figure(figsize=(10,5))
alpha = 3
beta = 0 
contrast_image = cv2.convertScaleAbs(DW, alpha=alpha, beta=beta)

# %%
plot_image(DW,contrast_image,"Orignal","contrast control")

# %%
plt.figure(figsize=(10,5))
plot_hist(DW, contrast_image,"Orignal","contrast control")

# %%
plt.figure(figsize=(10,5))
alpha = 3 
beta = -50 
new_image = cv2.convertScaleAbs(DW, alpha=alpha, beta=beta)

# %%
plot_image(DW, new_image, "Orignal", "brightness & contrast control")

# %%
plt.figure(figsize=(10,5))
plot_hist(DW, new_image, "Orignal", "brightness & contrast control")

# %% [markdown]
# # Histogram Equalization

# %%
DW1 = cv2.imread("DorisWang1.jpg",cv2.IMREAD_GRAYSCALE)
new_image = cv2.equalizeHist(DW1)

# %%
plot_image(DW1,new_image,"Orignal","Histogram Equalization")

# %%
plt.figure(figsize=(10,5))
plot_hist(DW1, new_image,"Orignal","Histogram Equalization")

# %% [markdown]
# # Thresholding and Simple Segmentation
# - If a particular pixel (i,j) is greater than that threshold it will set that pixel to some value usually 1 or 255, otherwise, it will set it to another value, usually zero

# %%
def thresholding(input_img,threshold,max_value=255, min_value=0):
    N,M=input_img.shape
    image_out=np.zeros((N,M),dtype=np.uint8)
        
    for i  in range(N):
        for j in range(M):
            if input_img[i,j]> threshold:
                image_out[i,j]=max_value
            else:
                image_out[i,j]=min_value
                
    return image_out

# %%
toy_image
# Out:
# array([[0, 2, 2],
#        [1, 1, 1],
#        [1, 1, 2]], dtype=uint8)

# %%
#setting all the values less than two to zero.
threshold = 1
max_value = 2
min_value = 0
thresholding_toy = thresholding(toy_image, threshold=threshold, max_value=max_value, min_value=min_value)
thresholding_toy
# Out:
# array([[0, 2, 2],
#        [0, 0, 0],
#        [0, 0, 2]], dtype=uint8)

# %%
plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(toy_image, cmap="gray")
plt.title("Original Image")

plt.subplot(1, 2, 2)
plt.imshow(thresholding_toy, cmap="gray")
plt.title("Image After Thresholding")
plt.show()

# %%
image = cv2.imread("cameraman.jpeg", cv2.IMREAD_GRAYSCALE)
plt.figure(figsize=(10, 10))
plt.imshow(image, cmap="gray")
plt.show()

# %%
hist = cv2.calcHist([image], [0], None, [256], [0, 256])
plt.bar(intensity_values, hist[:, 0], width=5)
plt.title("Bar histogram")
plt.show()

# %% [markdown]
# The histogram has two peaks-->there is a large proportion of pixels in those two ranges

# %%
threshold = 87
max_value = 255
min_value = 0
new_image = thresholding(image, threshold=threshold, max_value=max_value, min_value=min_value)

# %%
plot_image(image, new_image, "Orignal", "Image After Thresholding")

# %%
plt.figure(figsize=(10,5))
plot_hist(image, new_image, "Orignal", "Image After Thresholding")

# %%
cv2.THRESH_BINARY
# Out:
# 0

# %%
ret, new_image = cv2.threshold(image,threshold,max_value,cv2.THRESH_BINARY)
plot_image(image,new_image,"Orignal","Image After Thresholding")
plot_hist(image, new_image,"Orignal","Image After Thresholding")

# %%
#ret is the threshold value and new_image is the image after thresholding has been applied.
ret, new_image = cv2.threshold(image,86,255,cv2.THRESH_TRUNC)
#will not change the values if the pixels are less than the threshold value
plot_image(image,new_image,"Orignal","Image After Thresholding")
plot_hist(image, new_image,"Orignal","Image After Thresholding")

# %%
#avoids having to choose a value and determines it automatically
ret, otsu = cv2.threshold(image,0,255,cv2.THRESH_OTSU)
plot_image(image,otsu,"Orignal","Otsu")
plot_hist(image, otsu,"Orignal"," Otsu's method")
